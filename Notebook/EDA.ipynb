# %% [markdown]
# # Submission Pertama: Menyelesaikan Permasalahan Human Resources
#
# - Nama: Hafiizh Taufiqul Hakim
# - Email: 2012500720@student.budiluhur.ac.id
# - Id Dicoding: hafizhtaufiqul1002

# %% [markdown]
# # Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
dataset = "https://raw.githubusercontent.com/HafiizhTH/Human_Resources/main/Data/Data_to_Visualisasi.csv"

# %%
df = pd.read_csv(dataset)
df.head().T
# Out:
#                                                   0                       1  \
# Age                                              37                      51
# Attrition                           Karyawan Keluar         Karyawan Keluar
# BusinessTravel                        Travel_Rarely           Travel_Rarely
# DailyRate                                      1141                    1323
# Department                   Research & Development  Research & Development
# DistanceFromHome                                 11                       4
# Education                                   College                  Master
# EducationField                              Medical           Life Sciences
# EnvironmentSatisfaction                         Low                     Low
# Gender                                       Female                    Male
# HourlyRate                                       61                      34
# JobInvolvement                                  Low                    High
# JobLevel                                   Advanced                   Basic
# JobRole                   Healthcare Representative      Research Scientist
# JobSatisfaction                              Medium                    High
# MaritalStatus                               Married                 Married
# MonthlyIncome                                  4777                    2461
# MonthlyRate                                   14382                   10332
# NumCompaniesWorked                                5                       9
# OverTime                                         No                     Yes
# PercentSalaryHike                                15                      12
# PerformanceRating                              High                    High
# RelationshipSatisfaction                        Low                    High
# StockOptionLevel                          Very High                    High
# TotalWorkingYears                                15                      18
# TrainingTimesLastYear                             2                       2
# WorkLifeBalance                                 Low             Outstanding
# YearsAtCompany                                    1                      10
# YearsInCurrentRole                                0                       0
# YearsSinceLastPromotion                           0                       2
# YearsWithCurrManager                              0                       7
#
#                                            2                   3  \
# Age                                       42                  40
# Attrition                 Karyawan Beratahan  Karyawan Beratahan
# BusinessTravel             Travel_Frequently       Travel_Rarely
# DailyRate                                555                1124
# Department                             Sales               Sales
# DistanceFromHome                          26                   1
# Education                           Bachelor             College
# EducationField                     Marketing             Medical
# EnvironmentSatisfaction                 High              Medium
# Gender                                Female                Male
# HourlyRate                                77                  57
# JobInvolvement                          High                 Low
# JobLevel                            Advanced            Advanced
# JobRole                      Sales Executive     Sales Executive
# JobSatisfaction                       Medium           Very High
# MaritalStatus                        Married             Married
# MonthlyIncome                          13525                7457
# MonthlyRate                            14864               13273
# NumCompaniesWorked                         5                   2
# OverTime                                  No                 Yes
# PercentSalaryHike                         14                  22
# PerformanceRating                       High           Very High
# RelationshipSatisfaction           Very High                High
# StockOptionLevel                         Low                High
# TotalWorkingYears                         23                   6
# TrainingTimesLastYear                      2                   2
# WorkLifeBalance                  Outstanding                Good
# YearsAtCompany                            20                   4
# YearsInCurrentRole                         4                   3
# YearsSinceLastPromotion                    4                   0
# YearsWithCurrManager                       8                   2
#
#                                                4
# Age                                           55
# Attrition                        Karyawan Keluar
# BusinessTravel                     Travel_Rarely
# DailyRate                                    725
# Department                Research & Development
# DistanceFromHome                               2
# Education                               Bachelor
# EducationField                           Medical
# EnvironmentSatisfaction                Very High
# Gender                                      Male
# HourlyRate                                    78
# JobInvolvement                              High
# JobLevel                                Advanced
# JobRole                                  Manager
# JobSatisfaction                              Low
# MaritalStatus                            Married
# MonthlyIncome                              19859
# MonthlyRate                                21199
# NumCompaniesWorked                             5
# OverTime                                     Yes
# PercentSalaryHike                             13
# PerformanceRating                           High
# RelationshipSatisfaction               Very High
# StockOptionLevel                             Low
# TotalWorkingYears                             24
# TrainingTimesLastYear                          2
# WorkLifeBalance                        Excellent
# YearsAtCompany                                 5
# YearsInCurrentRole                             2
# YearsSinceLastPromotion                        1
# YearsWithCurrManager                           4

# %% [markdown]
# # EDA

# %% [markdown]
# ### Statistik Deskriptif

# %%
num = df.select_dtypes(exclude='object').columns
cat = df.select_dtypes(include='object').columns

# %%
# Statistik deskriptif untuk data numerik
df[num].describe()
# Out:
#                Age    DailyRate  DistanceFromHome   HourlyRate  MonthlyIncome  \
# count  1058.000000  1058.000000       1058.000000  1058.000000    1058.000000
# mean     37.055766   809.542533          8.978261    65.643667    6625.945180
# std       9.410421   408.478049          8.040608    20.324861    4837.695042
# min      18.000000   102.000000          1.000000    30.000000    1009.000000
# 25%      30.000000   465.250000          2.000000    48.000000    2900.250000
# 50%      36.000000   817.500000          7.000000    65.000000    4903.500000
# 75%      43.000000  1168.500000         13.000000    83.000000    8736.500000
# max      60.000000  1499.000000         29.000000   100.000000   19999.000000
#
#         MonthlyRate  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count   1058.000000         1058.000000        1058.000000        1058.000000
# mean   14267.281664            2.706994          15.155955          11.435728
# std     7048.077305            2.523526           3.641097           8.016429
# min     2094.000000            0.000000          11.000000           0.000000
# 25%     8277.250000            1.000000          12.000000           6.000000
# 50%    14201.000000            2.000000          14.000000          10.000000
# 75%    20364.000000            4.000000          18.000000          16.000000
# max    26999.000000            9.000000          25.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# count            1058.000000     1058.000000          1058.00000
# mean                2.769376        7.065217             4.26087
# std                 1.302689        6.265227             3.61747
# min                 0.000000        0.000000             0.00000
# 25%                 2.000000        3.000000             2.00000
# 50%                 3.000000        5.000000             3.00000
# 75%                 3.000000        9.000000             7.00000
# max                 6.000000       40.000000            18.00000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1058.000000           1058.000000
# mean                  2.203214              4.142722
# std                   3.266948              3.599044
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000

# %%
# Statistik deskriptif untuk data kategorik
df[cat].describe()
# Out:
#                  Attrition BusinessTravel              Department Education  \
# count                 1058           1058                    1058      1058
# unique                   2              3                       3         5
# top     Karyawan Beratahan  Travel_Rarely  Research & Development  Bachelor
# freq                   879            746                     701       410
#
#        EducationField EnvironmentSatisfaction Gender JobInvolvement  JobLevel  \
# count            1058                    1058   1058           1058      1058
# unique              6                       4      2              4         3
# top     Life Sciences                    High   Male           High  Advanced
# freq              436                     335    620            625       499
#
#                 JobRole JobSatisfaction MaritalStatus OverTime  \
# count              1058            1058          1058     1058
# unique                9               4             3        2
# top     Sales Executive       Very High       Married       No
# freq                232             340           464      751
#
#        PerformanceRating RelationshipSatisfaction StockOptionLevel  \
# count               1058                     1058             1058
# unique                 2                        4                4
# top                 High                     High        Very High
# freq                 899                      324              471
#
#        WorkLifeBalance
# count             1058
# unique               4
# top          Excellent
# freq               638

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Fitur Numerik

# %%
# Mengidentifikasi untuk kolom numerik
num_plots = len(num)
num_rows = (num_plots // 3) + 1
num_cols = 3

# %%
# Kde
rcParams['figure.figsize'] = 18, 5 * num_rows
for i in range(0, len(num)):
    plt.subplot(num_rows, num_cols, i+1)
    sns.kdeplot(x=df[num[i]], palette='#4793AF')
    plt.title(num[i], fontsize=12, fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()
# Out:
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')
# <ipython-input-8-f1c27da01609>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(x=df[num[i]], palette='#4793AF')

# %%
# Boxplot
rcParams['figure.figsize'] = 18, 5 * num_rows
for i in range(0, len(num)):
    plt.subplot(num_rows, num_cols, i+1)
    sns.boxplot(x=df[num[i]], color='#4793AF')
    plt.title(num[i], fontsize=12, fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ##### Fitur Kategorik

# %%
# Mengidentifikasi untuk kolom kategorik
cat_plots = len(cat)
cat_rows = (cat_plots // 2) + 1
cat_cols = 2

# %%
def generate_palette(series):
    max_val = series.value_counts().idxmax()
    min_val = series.value_counts().idxmin()
    colors = ['#DD5746' if val == min_val else '#FFC470' if val == max_val else '#4793AF' for val in series.unique()]
    return dict(zip(series.unique(), colors))

rcParams['figure.figsize'] = 18, 5 * cat_rows
for i in range(0, len(cat)):
    plt.subplot(cat_rows, cat_cols, i+1)
    palette = generate_palette(df[cat[i]])
    sns.countplot(y=df[cat[i]], palette=palette)
    plt.title(cat[i], fontweight='bold')
    plt.tight_layout(pad=2)
plt.show()
# Out:
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)
# <ipython-input-11-ed889b06d530>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[cat[i]], palette=palette)

# %% [markdown]
# ### Bivariate Analysis

# %%
# Membuat sebuah helper function bernama categorical_plot
def categorical_plot(features, df, segment_feature=None):
    fig, ax = plt.subplots(len(features), 1,figsize=(16,20))
    for i, feature in enumerate(features):
        if segment_feature:
            sns.countplot(data=df, x=segment_feature, hue=feature, ax=ax[i])
            ax[i].set_title(f'Grafik {feature} berdasarkan {segment_feature}', fontsize = 14, fontweight='bold')
            ax[i].set_xlabel(segment_feature, fontsize = 10)
        else:
            sns.countplot(data=df, x=feature, ax=ax[i])
    plt.tight_layout()
    plt.show()

# %%
# Membuat sebuah helper function bernama numerical_plot
def numerical_plot(features, df, segment_feature=None):
    fig, ax = plt.subplots(len(features), 1,figsize=(16,20))
    for i, feature in enumerate(features):
        if segment_feature:
            sns.countplot(data=df, x=feature, hue=segment_feature, ax=ax[i])
            ax[i].set_title(f'Grafik {feature} berdasarkan {segment_feature}', fontsize = 14, fontweight='bold')
            ax[i].set_xlabel(segment_feature, fontsize = 10)
        else:
            sns.countplot(data=df, x=feature, ax=ax[i])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### Hubungan Fitur Numerik dengan Fitur Attrition

# %%
numerical_plot(
    features=["Age", "DistanceFromHome", "YearsWithCurrManager", "TotalWorkingYears"],
    df=df,
    segment_feature="Attrition"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %% [markdown]
# ##### Hubungan Fitur Kategorik dengan Fitur JobRole

# %%
categorical_plot(
    features=["Gender", "Education", "EducationField"],
    df=df,
    segment_feature="JobRole"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %%
categorical_plot(
    features=["EnvironmentSatisfaction", "JobInvolvement", "OverTime", "JobLevel",
              "PerformanceRating", "RelationshipSatisfaction", "WorkLifeBalance"],
    df=df,
    segment_feature="JobRole"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %% [markdown]
# ##### Hubungan Fitur kategorik dengan Fitur Department

# %%
categorical_plot(
    features=["Gender", "Education", "EducationField"],
    df=df,
    segment_feature="Department"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %%
categorical_plot(
    features=["EnvironmentSatisfaction", "JobInvolvement", "OverTime",
              "PerformanceRating", "RelationshipSatisfaction", "WorkLifeBalance"],
    df=df,
    segment_feature="Department"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %% [markdown]
# ##### Hubungan Fitur Kategorik dengan Fitur Business Travel

# %%
categorical_plot(
    features=["Department", "JobRole"],
    df=df,
    segment_feature="BusinessTravel"
)

# %% [markdown]
# **Obervasi:**
# Teks

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ##### Hubungan dari setiap kolom

# %%
corr = df[num].corr()
plt.figure(figsize=(20, 16))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16, fontweight='bold')
plt.xticks(rotation=90, fontsize=16)
plt.yticks(rotation=0, fontsize=16)
plt.show()

# %% [markdown]
# **Obervasi:**
# Teks
